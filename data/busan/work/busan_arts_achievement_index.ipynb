# %% [markdown]
# # busan_arts_achievement_index

# %%
import pandas as pd
import numpy as np

# %%
# 부산시 구별 데이터
data = {
    '구': ['강서구', '금정구', '기장군', '남구', '동구', '동래구', '부산진구', '북구', '사상구', '사하구', '서구', '수영구', '연제구', '영도구', '중구', '해운대구'],
}
# 데이터 프레임 생성
final_art_achievement_index = pd.DataFrame(data)
final_art_achievement_index
# Out:
#        구
# 0    강서구
# 1    금정구
# 2    기장군
# 3     남구
# 4     동구
# 5    동래구
# 6   부산진구
# 7     북구
# 8    사상구
# 9    사하구
# 10    서구
# 11   수영구
# 12   연제구
# 13   영도구
# 14    중구
# 15  해운대구

# %%
arts_achievement_index = pd.read_csv('../Busan_data/arts_achievement_index_calculate.csv')
arts_achievement_index
# Out:
#        구  Average_satisfaction  Sum_of_willingness_to_watch  \
# 0    강서구              5.835556                      12.2556
# 1    금정구              5.835556                      12.2556
# 2    기장군              5.835556                      12.2556
# 3     남구              5.835556                      12.2556
# 4     동구              5.835556                      12.2556
# 5    동래구              5.835556                      12.2556
# 6   부산진구              5.835556                      12.2556
# 7     북구              5.835556                      12.2556
# 8    사상구              5.835556                      12.2556
# 9    사하구              5.835556                      12.2556
# 10    서구              5.835556                      12.2556
# 11   수영구              5.835556                      12.2556
# 12   연제구              5.835556                      12.2556
# 13   영도구              5.835556                      12.2556
# 14    중구              5.835556                      12.2556
# ...

# %% [markdown]
# ## 문화예술만족도 및 관람의향 (Arts and culture satisfaction and intent to attend)

# %%
# 부산시 구별 데이터
data = {
    '구': ['강서구', '금정구', '기장군', '남구', '동구', '동래구', '부산진구', '북구', '사상구', '사하구', '서구', '수영구', '연제구', '영도구', '중구', '해운대구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강서구
# 1    금정구
# 2    기장군
# 3     남구
# 4     동구
# 5    동래구
# 6   부산진구
# 7     북구
# 8    사상구
# 9    사하구
# 10    서구
# 11   수영구
# 12   연제구
# 13   영도구
# 14    중구
# 15  해운대구

# %%
Average_satisfaction_mean = arts_achievement_index['Average_satisfaction'].mean()
Average_satisfaction_mean
# Out:
# 5.835556

# %%
cal_df['Average_satisfaction'] = arts_achievement_index['Average_satisfaction']/Average_satisfaction_mean
cal_df
# Out:
#        구  Average_satisfaction
# 0    강서구                   1.0
# 1    금정구                   1.0
# 2    기장군                   1.0
# 3     남구                   1.0
# 4     동구                   1.0
# 5    동래구                   1.0
# 6   부산진구                   1.0
# 7     북구                   1.0
# 8    사상구                   1.0
# 9    사하구                   1.0
# 10    서구                   1.0
# 11   수영구                   1.0
# 12   연제구                   1.0
# 13   영도구                   1.0
# 14    중구                   1.0
# 15  해운대구                   1.0

# %%
Sum_of_willingness_to_watch_mean = arts_achievement_index['Sum_of_willingness_to_watch'].mean()
Sum_of_willingness_to_watch_mean
# Out:
# 12.2556

# %%
cal_df['Sum_of_willingness_to_watch'] = arts_achievement_index['Sum_of_willingness_to_watch']/Sum_of_willingness_to_watch_mean
cal_df
# Out:
#        구  Average_satisfaction  Sum_of_willingness_to_watch
# 0    강서구                   1.0                          1.0
# 1    금정구                   1.0                          1.0
# 2    기장군                   1.0                          1.0
# 3     남구                   1.0                          1.0
# 4     동구                   1.0                          1.0
# 5    동래구                   1.0                          1.0
# 6   부산진구                   1.0                          1.0
# 7     북구                   1.0                          1.0
# 8    사상구                   1.0                          1.0
# 9    사하구                   1.0                          1.0
# 10    서구                   1.0                          1.0
# 11   수영구                   1.0                          1.0
# 12   연제구                   1.0                          1.0
# 13   영도구                   1.0                          1.0
# 14    중구                   1.0                          1.0
# ...

# %%
cal_df['Arts_and_culture_satisfaction_and_intent_to_attend'] = (cal_df['Average_satisfaction'] + cal_df['Sum_of_willingness_to_watch'])/2
cal_df['Arts_and_culture_satisfaction_and_intent_to_attend'] = cal_df['Arts_and_culture_satisfaction_and_intent_to_attend']*100
cal_df
# Out:
#        구  Average_satisfaction  Sum_of_willingness_to_watch  \
# 0    강서구                   1.0                          1.0
# 1    금정구                   1.0                          1.0
# 2    기장군                   1.0                          1.0
# 3     남구                   1.0                          1.0
# 4     동구                   1.0                          1.0
# 5    동래구                   1.0                          1.0
# 6   부산진구                   1.0                          1.0
# 7     북구                   1.0                          1.0
# 8    사상구                   1.0                          1.0
# 9    사하구                   1.0                          1.0
# 10    서구                   1.0                          1.0
# 11   수영구                   1.0                          1.0
# 12   연제구                   1.0                          1.0
# 13   영도구                   1.0                          1.0
# 14    중구                   1.0                          1.0
# ...

# %%
final_art_achievement_index['sat_intent'] = cal_df['Arts_and_culture_satisfaction_and_intent_to_attend']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 문화예술교육만족도 및 수강의향

# %%
Satisfaction_intention_arts_education_mean = arts_achievement_index['Satisfaction_intention_arts_education'].mean()
Satisfaction_intention_arts_education_mean
# Out:
# 390.0

# %%
final_art_achievement_index['edu_intent'] = (arts_achievement_index['Satisfaction_intention_arts_education']/Satisfaction_intention_arts_education_mean)*100
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 여가생활 만족도

# %%
Leisure_satisfaction_mean = arts_achievement_index['Leisure_satisfaction'].mean()
Leisure_satisfaction_mean
# Out:
# 0.14398955372620106

# %%
final_art_achievement_index['sat_leisure'] = (arts_achievement_index['Leisure_satisfaction']/Leisure_satisfaction_mean)*100
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 행복 및 삶의질 (Happiness and quality of life)

# %%
# 부산시 구별 데이터
data = {
    '구': ['강서구', '금정구', '기장군', '남구', '동구', '동래구', '부산진구', '북구', '사상구', '사하구', '서구', '수영구', '연제구', '영도구', '중구', '해운대구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강서구
# 1    금정구
# 2    기장군
# 3     남구
# 4     동구
# 5    동래구
# 6   부산진구
# 7     북구
# 8    사상구
# 9    사하구
# 10    서구
# 11   수영구
# 12   연제구
# 13   영도구
# 14    중구
# 15  해운대구

# %%
cal_df['Happiness_level'] = arts_achievement_index['Happiness_level']
cal_df['Quality_of_life'] = arts_achievement_index['Quality_of_life']
cal_df
# Out:
#        구  Happiness_level  Quality_of_life
# 0    강서구         0.330334         0.479928
# 1    금정구         0.461744         0.536850
# 2    기장군         0.473784         0.437427
# 3     남구         0.427650         0.553098
# 4     동구         0.531745         0.036110
# 5    동래구         0.523733         0.643667
# 6   부산진구         0.447026         0.423916
# 7     북구         0.363738         0.306465
# 8    사상구         0.403220         0.090277
# 9    사하구         0.317932         0.110362
# 10    서구         0.532875         0.304445
# 11   수영구         0.417241         0.346696
# 12   연제구         0.419896         0.642823
# 13   영도구         0.351800         0.227300
# 14    중구         0.603554         0.022514
# 15  해운대구         0.391456         0.631429

# %%
Happiness_level_mean= arts_achievement_index['Happiness_level'].mean()
Happiness_level_mean
# Out:
# 0.43735786715913627

# %%
Quality_of_life_mean = arts_achievement_index['Quality_of_life'].mean()
Quality_of_life_mean
# Out:
# 0.36208167223939314

# %%
cal_df['Happiness_level'] = (arts_achievement_index['Happiness_level']/Happiness_level_mean)*100
cal_df['Quality_of_life'] = (arts_achievement_index['Quality_of_life']/Quality_of_life_mean)*100
cal_df
# Out:
#        구  Happiness_level  Quality_of_life
# 0    강서구        75.529363       132.546819
# 1    금정구       105.575808       148.267745
# 2    기장군       108.328596       120.808856
# 3     남구        97.780269       152.755087
# 4     동구       121.581139         9.972828
# 5    동래구       119.749279       177.768328
# 6   부산진구       102.210514       117.077388
# 7     북구        83.167081        84.639697
# 8    사상구        92.194587        24.932719
# 9    사하구        72.693746        30.479922
# 10    서구       121.839669        84.081862
# 11   수영구        95.400304        95.750795
# 12   연제구        96.007511       177.535349
# 13   영도구        80.437561        62.775892
# 14    중구       137.999946         6.218033
# 15  해운대구        89.504628       174.388679

# %%
final_art_achievement_index['Happy_life'] = (cal_df['Happiness_level'] + cal_df['Quality_of_life'])/2
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 공연시장매출액

# %%
arts_achievement_index
# Out:
#        구  Average_satisfaction  Sum_of_willingness_to_watch  \
# 0    강서구              5.835556                      12.2556
# 1    금정구              5.835556                      12.2556
# 2    기장군              5.835556                      12.2556
# 3     남구              5.835556                      12.2556
# 4     동구              5.835556                      12.2556
# 5    동래구              5.835556                      12.2556
# 6   부산진구              5.835556                      12.2556
# 7     북구              5.835556                      12.2556
# 8    사상구              5.835556                      12.2556
# 9    사하구              5.835556                      12.2556
# 10    서구              5.835556                      12.2556
# 11   수영구              5.835556                      12.2556
# 12   연제구              5.835556                      12.2556
# 13   영도구              5.835556                      12.2556
# 14    중구              5.835556                      12.2556
# ...

# %%
Performance_market_revenue_mean = arts_achievement_index['Performance_market_revenue'].mean()
Performance_market_revenue_mean
# Out:
# 493266.0

# %%
final_art_achievement_index['perf_revenue'] = (arts_achievement_index['Performance_market_revenue']/Performance_market_revenue_mean)*100
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 미술시장매출액

# %%
Art_market_revenue_mean = arts_achievement_index['Art_market_revenue'].mean()
Art_market_revenue_mean
# Out:
# 5946.0

# %%
final_art_achievement_index['art_revenue'] = (arts_achievement_index['Art_market_revenue']/Art_market_revenue_mean)*100
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 문화예술 국제교류 건수

# %%
Cultural_exchanges_mean = arts_achievement_index['Cultural_exchanges'].mean()
Cultural_exchanges_mean
# Out:
# 9.03

# %%
final_art_achievement_index['global_exchange'] = (arts_achievement_index['Cultural_exchanges']/Cultural_exchanges_mean)*100
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 향유결과지수

# %%
final_art_achievement_index['enjoyment_outcome_index'] = (final_art_achievement_index['sat_intent'] + final_art_achievement_index['edu_intent'] + final_art_achievement_index['sat_leisure'] + final_art_achievement_index['happy_life'])/4
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 시장성과지수

# %%
final_art_achievement_index['market_performance_index'] = (final_art_achievement_index['perf_revenue'] + final_art_achievement_index['art_revenue'] + final_art_achievement_index['global_exchange'])/3
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %% [markdown]
# ## 예술성과지수

# %%
final_art_achievement_index['busan_arts_achievement_index'] = (final_art_achievement_index['enjoyment_outcome_index'] + final_art_achievement_index['market_performance_index'])/2
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강서구                                              100.0
# 1    금정구                                              100.0
# 2    기장군                                              100.0
# 3     남구                                              100.0
# 4     동구                                              100.0
# 5    동래구                                              100.0
# 6   부산진구                                              100.0
# 7     북구                                              100.0
# 8    사상구                                              100.0
# 9    사하구                                              100.0
# 10    서구                                              100.0
# 11   수영구                                              100.0
# 12   연제구                                              100.0
# 13   영도구                                              100.0
# 14    중구                                              100.0
# ...

# %%
final_art_achievement_index.to_csv('busan_arts_achievement_index.csv', encoding='utf-8-sig', index=False)
