# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd

# %%
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
Seoul_arts_index = pd.DataFrame(data)
Seoul_arts_index
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
arts_creation_production_index = pd.read_csv('/content/arts_creation_production_index.csv')
arts_finance_index = pd.read_csv('/content/arts_finance_index.csv')
arts_facilities_index = pd.read_csv('/content/arts_facilities_index.csv')
arts_enjoyment_index = pd.read_csv('/content/arts_enjoyment_index.csv')
arts_achievement_index = pd.read_csv('/content/arts_achievement_index.csv')

# %% [markdown]
# ## 예술창작/생산지수

# %%
Seoul_arts_index['예술창작/생산지수'] = arts_creation_production_index['arts_creation_production_index']
Seoul_arts_index
# Out:
#        구  예술창작/생산지수
# 0    강남구     108.46
# 1    강동구     108.46
# 2    강북구     108.46
# 3    강서구     108.46
# 4    관악구     108.46
# 5    광진구     108.46
# 6    구로구     108.46
# 7    금천구     108.46
# 8    노원구     108.46
# 9    도봉구     108.46
# 10  동대문구     108.46
# 11   동작구     108.46
# 12   마포구     108.46
# 13  서대문구     108.46
# 14   서초구     108.46
# 15   성동구     108.46
# 16   성북구     108.46
# 17   송파구     108.46
# 18   양천구     108.46
# 19  영등포구     108.46
# 20   용산구     108.46
# 21   은평구     108.46
# 22   종로구     108.46
# 23    중구     108.46
# 24   중랑구     108.46

# %% [markdown]
# ## 예술재정지수

# %%
Seoul_arts_index['예술재정지수'] = arts_finance_index['arts_finance_index']
Seoul_arts_index
# Out:
#        구  예술창작/생산지수  예술재정지수
# 0    강남구     108.46  172.60
# 1    강동구     108.46  129.14
# 2    강북구     108.46   49.80
# 3    강서구     108.46   83.56
# 4    관악구     108.46  102.88
# 5    광진구     108.46  257.64
# 6    구로구     108.46   53.14
# 7    금천구     108.46   51.47
# 8    노원구     108.46  102.10
# 9    도봉구     108.46   49.80
# 10  동대문구     108.46   99.80
# 11   동작구     108.46   49.80
# 12   마포구     108.46   99.80
# 13  서대문구     108.46  102.80
# 14   서초구     108.46  384.94
# 15   성동구     108.46  138.95
# 16   성북구     108.46   97.61
# 17   송파구     108.46   70.04
# 18   양천구     108.46   99.80
# 19  영등포구     108.46   57.08
# 20   용산구     108.46   49.80
# 21   은평구     108.46  822.02
# 22   종로구     108.46   99.80
# 23    중구     108.46   99.80
# 24   중랑구     108.46  102.80

# %% [markdown]
# ## 예술시설지수

# %%
Seoul_arts_index['예술시설지수'] = arts_facilities_index['arts_facilities_index']
Seoul_arts_index
# Out:
#        구  예술창작/생산지수  예술재정지수  예술시설지수
# 0    강남구     108.46  172.60   99.76
# 1    강동구     108.46  129.14   99.76
# 2    강북구     108.46   49.80  100.00
# 3    강서구     108.46   83.56  101.31
# 4    관악구     108.46  102.88   99.28
# 5    광진구     108.46  257.64  100.89
# 6    구로구     108.46   53.14   99.60
# 7    금천구     108.46   51.47   99.24
# 8    노원구     108.46  102.10   99.93
# 9    도봉구     108.46   49.80   99.99
# 10  동대문구     108.46   99.80   99.50
# 11   동작구     108.46   49.80   99.82
# 12   마포구     108.46   99.80   99.96
# 13  서대문구     108.46  102.80   99.53
# 14   서초구     108.46  384.94  100.55
# 15   성동구     108.46  138.95  100.14
# 16   성북구     108.46   97.61   99.69
# 17   송파구     108.46   70.04   99.70
# 18   양천구     108.46   99.80   99.98
# 19  영등포구     108.46   57.08   99.51
# 20   용산구     108.46   49.80  100.82
# 21   은평구     108.46  822.02   99.94
# 22   종로구     108.46   99.80  100.58
# 23    중구     108.46   99.80   99.66
# 24   중랑구     108.46  102.80   99.72

# %% [markdown]
# ## 예술향유지수

# %%
Seoul_arts_index['예술향유지수'] = arts_enjoyment_index['arts_enjoyment_index']
Seoul_arts_index
# Out:
#        구  예술창작/생산지수  예술재정지수  예술시설지수  예술향유지수
# 0    강남구     108.46  172.60   99.76  104.97
# 1    강동구     108.46  129.14   99.76  115.37
# 2    강북구     108.46   49.80  100.00  110.50
# 3    강서구     108.46   83.56  101.31  102.50
# 4    관악구     108.46  102.88   99.28  121.54
# 5    광진구     108.46  257.64  100.89  103.21
# 6    구로구     108.46   53.14   99.60  116.42
# 7    금천구     108.46   51.47   99.24  103.86
# 8    노원구     108.46  102.10   99.93  108.58
# 9    도봉구     108.46   49.80   99.99  129.14
# 10  동대문구     108.46   99.80   99.50  171.21
# 11   동작구     108.46   49.80   99.82  145.58
# 12   마포구     108.46   99.80   99.96  118.73
# 13  서대문구     108.46  102.80   99.53  112.02
# 14   서초구     108.46  384.94  100.55  138.94
# 15   성동구     108.46  138.95  100.14  104.28
# 16   성북구     108.46   97.61   99.69  111.00
# 17   송파구     108.46   70.04   99.70  103.87
# 18   양천구     108.46   99.80   99.98  113.40
# 19  영등포구     108.46   57.08   99.51   92.50
# 20   용산구     108.46   49.80  100.82  142.61
# 21   은평구     108.46  822.02   99.94  141.79
# 22   종로구     108.46   99.80  100.58  127.39
# 23    중구     108.46   99.80   99.66  117.50
# 24   중랑구     108.46  102.80   99.72  127.77

# %% [markdown]
# ## 예술성과지수

# %%
Seoul_arts_index['예술성과지수'] = arts_achievement_index['arts_achievement_index']
Seoul_arts_index
# Out:
#        구  예술창작/생산지수  예술재정지수  예술시설지수  예술향유지수  예술성과지수
# 0    강남구     108.46  172.60   99.76  104.97  105.56
# 1    강동구     108.46  129.14   99.76  115.37  106.11
# 2    강북구     108.46   49.80  100.00  110.50   96.98
# 3    강서구     108.46   83.56  101.31  102.50  113.34
# 4    관악구     108.46  102.88   99.28  121.54  119.46
# 5    광진구     108.46  257.64  100.89  103.21  115.13
# 6    구로구     108.46   53.14   99.60  116.42   92.15
# 7    금천구     108.46   51.47   99.24  103.86   92.04
# 8    노원구     108.46  102.10   99.93  108.58   90.03
# 9    도봉구     108.46   49.80   99.99  129.14   91.03
# 10  동대문구     108.46   99.80   99.50  171.21  127.03
# 11   동작구     108.46   49.80   99.82  145.58  100.94
# 12   마포구     108.46   99.80   99.96  118.73   99.68
# 13  서대문구     108.46  102.80   99.53  112.02  101.56
# 14   서초구     108.46  384.94  100.55  138.94   92.18
# 15   성동구     108.46  138.95  100.14  104.28  112.34
# 16   성북구     108.46   97.61   99.69  111.00  122.42
# 17   송파구     108.46   70.04   99.70  103.87  106.26
# 18   양천구     108.46   99.80   99.98  113.40   98.27
# 19  영등포구     108.46   57.08   99.51   92.50   83.67
# 20   용산구     108.46   49.80  100.82  142.61  101.28
# 21   은평구     108.46  822.02   99.94  141.79  101.78
# 22   종로구     108.46   99.80  100.58  127.39  107.82
# 23    중구     108.46   99.80   99.66  117.50  102.74
# 24   중랑구     108.46  102.80   99.72  127.77  109.98

# %% [markdown]
# ## Arts Index

# %%
Seoul_arts_index['서울예술활력지수'] = arts_creation_production_index['arts_creation_production_index'] + arts_finance_index['arts_finance_index'] + arts_facilities_index['arts_facilities_index'] + arts_enjoyment_index['arts_enjoyment_index'] + arts_achievement_index['arts_achievement_index']
Seoul_arts_index['서울예술활력지수'] = Seoul_arts_index['서울예술활력지수']/5
Seoul_arts_index['서울예술활력지수'] = Seoul_arts_index['서울예술활력지수'].round(2)
Seoul_arts_index
# Out:
#        구  예술창작/생산지수  예술재정지수  예술시설지수  예술향유지수  예술성과지수  서울예술활력지수
# 0    강남구     108.46  172.60   99.76  104.97  105.56    118.27
# 1    강동구     108.46  129.14   99.76  115.37  106.11    111.77
# 2    강북구     108.46   49.80  100.00  110.50   96.98     93.15
# 3    강서구     108.46   83.56  101.31  102.50  113.34    101.83
# 4    관악구     108.46  102.88   99.28  121.54  119.46    110.32
# 5    광진구     108.46  257.64  100.89  103.21  115.13    137.07
# 6    구로구     108.46   53.14   99.60  116.42   92.15     93.95
# 7    금천구     108.46   51.47   99.24  103.86   92.04     91.01
# 8    노원구     108.46  102.10   99.93  108.58   90.03    101.82
# 9    도봉구     108.46   49.80   99.99  129.14   91.03     95.68
# 10  동대문구     108.46   99.80   99.50  171.21  127.03    121.20
# 11   동작구     108.46   49.80   99.82  145.58  100.94    100.92
# 12   마포구     108.46   99.80   99.96  118.73   99.68    105.33
# 13  서대문구     108.46  102.80   99.53  112.02  101.56    104.87
# 14   서초구     108.46  384.94  100.55  138.94   92.18    165.01
# 15   성동구     108.46  138.95  100.14  104.28  112.34    112.83
# 16   성북구     108.46   97.61   99.69  111.00  122.42    107.84
# 17   송파구     108.46   70.04   99.70  103.87  106.26     97.67
# 18   양천구     108.46   99.80   99.98  113.40   98.27    103.98
# 19  영등포구     108.46   57.08   99.51   92.50   83.67     88.24
# 20   용산구     108.46   49.80  100.82  142.61  101.28    100.59
# 21   은평구     108.46  822.02   99.94  141.79  101.78    254.80
# 22   종로구     108.46   99.80  100.58  127.39  107.82    108.81
# 23    중구     108.46   99.80   99.66  117.50  102.74    105.63
# 24   중랑구     108.46  102.80   99.72  127.77  109.98    109.75

# %%
summary = Seoul_arts_index.describe()
summary
# Out:
#        예술창작/생산지수      예술재정지수      예술시설지수      예술향유지수      예술성과지수   서울예술활력지수
# count      25.00   25.000000   25.000000   25.000000   25.000000   25.00000
# mean      108.46  137.078800   99.954400  119.387200  103.591200  113.69360
# std         0.00  160.506438    0.512039   17.797672   10.757555   33.37722
# min       108.46   49.800000   99.240000   92.500000   83.670000   88.24000
# 25%       108.46   57.080000   99.660000  104.970000   96.980000  100.59000
# 50%       108.46   99.800000   99.820000  115.370000  101.780000  105.33000
# 75%       108.46  102.880000  100.000000  127.770000  109.980000  111.77000
# max       108.46  822.020000  101.310000  171.210000  127.030000  254.80000

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

Seoul_arts_index['서울예술활력지수'].plot(kind='bar')
plt.title('서울예술활력지수')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
Seoul_arts_index.to_csv('Seoul_arts_index.csv', encoding='utf-8-sig', index=False)
