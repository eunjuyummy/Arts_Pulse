# %% [markdown]
# # art_achievement_index

# %%
import pandas as pd
import numpy as np

# %%
# 최종 지표 값들을 정리할 table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
final_art_achievement_index= pd.DataFrame(data)
final_art_achievement_index
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
art_achievement_index = pd.read_csv('../Seoul_data/art_achievement_index.csv')
art_achievement_index
# Out:
#        구  happiness_2021  happiness_2022  Aacs_2021  Aacs_2022  Aacitt_2021  \
# 0    강남구            6.53            6.35       5.65    5.56222        150.9
# 1    강동구            6.27            6.86       5.65    5.56222        150.9
# 2    강북구            6.18            6.52       5.65    5.56222        150.9
# 3    강서구            6.13            6.37       5.65    5.56222        150.9
# 4    관악구            6.23            6.73       5.65    5.56222        150.9
# 5    광진구            6.38            6.53       5.65    5.56222        150.9
# 6    구로구            6.29            6.48       5.65    5.56222        150.9
# 7    금천구            6.19            6.37       5.65    5.56222        150.9
# 8    노원구            6.38            6.59       5.65    5.56222        150.9
# 9    도봉구            6.06            6.62       5.65    5.56222        150.9
# 10  동대문구            6.24            6.76       5.65    5.56222        150.9
# ...

# %% [markdown]
# ## 문화예술만족도 및 관람의향 (Arts and culture satisfaction and intent to attend)

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# (Aacs_2022 / Aacs_2021, Avg(Aacitt_2022/Aacitt_2021))*100
cal_df['Aacs'] = art_achievement_index['Aacs_2022']/art_achievement_index['Aacs_2021']
cal_df['Aacitt'] = (art_achievement_index['Aacitt_2022']/art_achievement_index['Aacitt_2021'])/9
cal_df['Aacs_Aacitt'] = (cal_df['Aacs'] + cal_df['Aacitt'])/2*100
cal_df
# Out:
#        구      Aacs    Aacitt  Aacs_Aacitt
# 0    강남구  0.984464  0.129298      55.6881
# 1    강동구  0.984464  0.129298      55.6881
# 2    강북구  0.984464  0.129298      55.6881
# 3    강서구  0.984464  0.129298      55.6881
# 4    관악구  0.984464  0.129298      55.6881
# 5    광진구  0.984464  0.129298      55.6881
# 6    구로구  0.984464  0.129298      55.6881
# 7    금천구  0.984464  0.129298      55.6881
# 8    노원구  0.984464  0.129298      55.6881
# 9    도봉구  0.984464  0.129298      55.6881
# 10  동대문구  0.984464  0.129298      55.6881
# 11   동작구  0.984464  0.129298      55.6881
# 12   마포구  0.984464  0.129298      55.6881
# 13  서대문구  0.984464  0.129298      55.6881
# 14   서초구  0.984464  0.129298      55.6881
# 15   성동구  0.984464  0.129298      55.6881
# 16   성북구  0.984464  0.129298      55.6881
# 17   송파구  0.984464  0.129298      55.6881
# 18   양천구  0.984464  0.129298      55.6881
# 19  영등포구  0.984464  0.129298      55.6881
# 20   용산구  0.984464  0.129298      55.6881
# ...

# %%
final_art_achievement_index['Arts_and_culture_satisfaction_and_intent_to_attend'] = cal_df['Aacs_Aacitt']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 문화예술교육만족도 및 수강의향

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# Avg((Aacs_2022 / Aacs_2021), Avg(Aacitt_2022/Aacitt_2021))*100
cal_df['Swaace'] = art_achievement_index['Swaace_2022']/art_achievement_index['Swaace_2021']
cal_df['Swaace'] = cal_df['Swaace']*100
cal_df
# Out:
#        구      Swaace
# 0    강남구   94.711538
# 1    강동구  111.829945
# 2    강북구  102.782324
# 3    강서구  111.743119
# 4    관악구   99.300699
# 5    광진구   98.954704
# 6    구로구  105.688073
# 7    금천구  103.249097
# 8    노원구  100.716846
# 9    도봉구  104.074074
# 10  동대문구  116.176471
# 11   동작구  113.380282
# 12   마포구  105.354059
# 13  서대문구  102.605863
# 14   서초구   98.543689
# 15   성동구  103.883495
# 16   성북구   99.309154
# 17   송파구  101.130856
# 18   양천구  102.985075
# 19  영등포구   77.396022
# 20   용산구  104.963235
# 21   은평구  118.035714
# 22   종로구  120.976492
# 23    중구   95.461912
# 24   중랑구  106.593407

# %%
final_art_achievement_index['Satisfaction_and_intention_to_take_arts_education'] = cal_df['Swaace']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 여가생활 만족도

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# (Lls_2022/Lls_2021)*100
cal_df['Lls'] = art_achievement_index['Lls_2022']/art_achievement_index['Lls_2021']
cal_df['Lls'] = cal_df['Lls']*100
cal_df
# Out:
#        구         Lls
# 0    강남구   92.629816
# 1    강동구  109.906542
# 2    강북구  103.793103
# 3    강서구  109.444444
# 4    관악구   94.179894
# 5    광진구  100.000000
# 6    구로구   99.450549
# 7    금천구  101.094891
# 8    노원구   98.387097
# 9    도봉구  102.962963
# 10  동대문구  112.500000
# 11   동작구  109.090909
# 12   마포구  103.146853
# 13  서대문구  103.247863
# 14   서초구   96.949153
# 15   성동구  105.245347
# 16   성북구   98.947368
# 17   송파구  103.378378
# 18   양천구  102.075472
# 19  영등포구   73.345588
# 20   용산구  103.846154
# 21   은평구  116.330275
# 22   종로구  115.855856
# 23    중구   96.959459
# 24   중랑구  106.296296

# %%
final_art_achievement_index['Satisfaction_with_leisure_time'] = cal_df['Lls']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 행복 및 삶의질 (Happiness and quality of life)

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# (happiness_2022/happiness_2021)
cal_df['happiness'] = art_achievement_index['happiness_2022']/art_achievement_index['happiness_2021']
cal_df['happiness'] = cal_df['happiness']*100
cal_df['Qol'] = art_achievement_index['Qof_2022']/art_achievement_index['Qof_2021']
cal_df['Qol'] = cal_df['Qol']*100
cal_df['happiness_Qol'] = (cal_df['happiness'] + cal_df['Qol'])/2
cal_df['happiness_Qol']
cal_df
# Out:
#        구   happiness         Qol  happiness_Qol
# 0    강남구   97.243492  112.006579     104.625035
# 1    강동구  109.409888  113.605442     111.507665
# 2    강북구  105.501618  114.907873     110.204745
# 3    강서구  103.915171  112.286689     108.100930
# 4    관악구  108.025682  111.243612     109.634647
# 5    광진구  102.351097  108.061750     105.206423
# 6    구로구  103.020668  109.152542     106.086605
# 7    금천구  102.907916  104.230118     103.569017
# 8    노원구  103.291536  132.046980     117.669258
# 9    도봉구  109.240924  105.488851     107.364887
# 10  동대문구  108.333333  113.310580     110.821957
# 11   동작구  111.792453  113.949580     112.871016
# 12   마포구  109.856916  107.046980     108.451948
# 13  서대문구  113.278689  113.289037     113.283863
# 14   서초구  109.090909  119.180328     114.135618
# 15   성동구  111.305732  112.919463     112.112598
# 16   성북구  112.277868  108.403361     110.340614
# 17   송파구  109.457364  114.784053     112.120709
# 18   양천구  107.131012  101.706485     104.418748
# ...

# %%
final_art_achievement_index['Happiness_and_quality_of_life'] = cal_df['happiness_Qol']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 공연시장매출액

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# (ms_2022/ms_2021)*100
cal_df['ms'] = art_achievement_index['ms_2022']/art_achievement_index['ms_2021']
cal_df['ms'] = cal_df['ms']*100
cal_df
# Out:
#        구          ms
# 0    강남구  172.596631
# 1    강동구  144.956360
# 2    강북구  102.522284
# 3    강서구  191.339897
# 4    관악구  247.627710
# 5    광진구  220.903536
# 6    구로구   77.694888
# 7    금천구   79.524537
# 8    노원구   60.811150
# 9    도봉구   68.610274
# 10  동대문구  265.786952
# 11   동작구  112.337304
# 12   마포구  118.641755
# 13  서대문구  128.195600
# 14   서초구   79.088004
# 15   성동구  191.316689
# 16   성북구  261.289024
# 17   송파구  158.288184
# 18   양천구  115.717331
# 19  영등포구   77.264432
# 20   용산구  128.280077
# 21   은평구  108.405373
# 22   종로구  143.582315
# 23    중구  153.457792
# 24   중랑구  176.837225

# %%
final_art_achievement_index['Performance_marketplace_sales'] = cal_df['ms']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 미술시장매출액

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# (Ams_2021/Ams_2021)*100 ----> 2022년 데이터가 존재하지 않기 때문에 지표 값이 1.00
cal_df['Ams'] = art_achievement_index['Ams_2021']/art_achievement_index['Ams_2021']
cal_df['Ams'] = cal_df['Ams']*100
cal_df
# Out:
#        구    Ams
# 0    강남구  100.0
# 1    강동구  100.0
# 2    강북구  100.0
# 3    강서구  100.0
# 4    관악구  100.0
# 5    광진구  100.0
# 6    구로구  100.0
# 7    금천구  100.0
# 8    노원구  100.0
# 9    도봉구  100.0
# 10  동대문구  100.0
# 11   동작구  100.0
# 12   마포구  100.0
# 13  서대문구  100.0
# 14   서초구  100.0
# 15   성동구  100.0
# 16   성북구  100.0
# 17   송파구  100.0
# 18   양천구  100.0
# 19  영등포구  100.0
# 20   용산구  100.0
# 21   은평구  100.0
# 22   종로구  100.0
# 23    중구  100.0
# 24   중랑구  100.0

# %%
final_art_achievement_index['Art_market_sales'] = cal_df['Ams']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 문화예술 국제교류 건수

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
# (Noce_2019/Noce_2019)*100 ----> 2019년 데이터만 존재하지 않기 때문에 지표 값이 1.00
cal_df['Noce'] = art_achievement_index['Noce_2019']/art_achievement_index['Noce_2019']
cal_df['Noce'] = cal_df['Noce']*100
cal_df
# Out:
#        구   Noce
# 0    강남구  100.0
# 1    강동구  100.0
# 2    강북구  100.0
# 3    강서구  100.0
# 4    관악구  100.0
# 5    광진구  100.0
# 6    구로구  100.0
# 7    금천구  100.0
# 8    노원구  100.0
# 9    도봉구  100.0
# 10  동대문구  100.0
# 11   동작구  100.0
# 12   마포구  100.0
# 13  서대문구  100.0
# 14   서초구  100.0
# 15   성동구  100.0
# 16   성북구  100.0
# 17   송파구  100.0
# 18   양천구  100.0
# 19  영등포구  100.0
# 20   용산구  100.0
# 21   은평구  100.0
# 22   종로구  100.0
# 23    중구  100.0
# 24   중랑구  100.0

# %%
final_art_achievement_index['Number_of_international_cultural_exchanges'] = cal_df['Noce']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 향유결과지수

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
cal_df['Enjoyment_Outcome_Index'] = final_art_achievement_index['Arts_and_culture_satisfaction_and_intent_to_attend'] + final_art_achievement_index['Satisfaction_and_intention_to_take_arts_education'] + final_art_achievement_index['Satisfaction_with_leisure_time'] + final_art_achievement_index['Happiness_and_quality_of_life']
cal_df['Enjoyment_Outcome_Index'] = cal_df['Enjoyment_Outcome_Index']/4
cal_df
# Out:
#        구  Enjoyment_Outcome_Index
# 0    강남구                86.913622
# 1    강동구                97.233063
# 2    강북구                93.117068
# 3    강서구                96.244149
# 4    관악구                89.700835
# 5    광진구                89.962307
# 6    구로구                91.728332
# 7    금천구                90.900276
# 8    노원구                93.115325
# 9    도봉구                92.522506
# 10  동대문구                98.796632
# 11   동작구                97.757577
# 12   마포구                93.160240
# 13  서대문구                93.706422
# 14   서초구                91.329140
# 15   성동구                94.232385
# 16   성북구                91.071309
# 17   송파구                93.079511
# 18   양천구                91.291849
# 19  영등포구                74.920449
# 20   용산구                93.143867
# 21   은평구               100.769188
# 22   종로구               101.121373
# 23    중구                87.665943
# 24   중랑구                94.360319

# %%
final_art_achievement_index['Enjoyment_Outcome_Index'] = cal_df['Enjoyment_Outcome_Index']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %% [markdown]
# ## 시장성과지수

# %%
# 계산을 위한 Table
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
cal_df = pd.DataFrame(data)
cal_df
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
cal_df['Market_Performance_Index'] = final_art_achievement_index['Performance_marketplace_sales'] + final_art_achievement_index['Art_market_sales'] + final_art_achievement_index['Number_of_international_cultural_exchanges']
cal_df['Market_Performance_Index'] = cal_df['Market_Performance_Index']/3
cal_df
# Out:
#        구  Market_Performance_Index
# 0    강남구                124.198877
# 1    강동구                114.985453
# 2    강북구                100.840761
# 3    강서구                130.446632
# 4    관악구                149.209237
# 5    광진구                140.301179
# 6    구로구                 92.564963
# 7    금천구                 93.174846
# 8    노원구                 86.937050
# 9    도봉구                 89.536758
# 10  동대문구                155.262317
# 11   동작구                104.112435
# 12   마포구                106.213918
# 13  서대문구                109.398533
# 14   서초구                 93.029335
# 15   성동구                130.438896
# 16   성북구                153.763008
# 17   송파구                119.429395
# 18   양천구                105.239110
# 19  영등포구                 92.421477
# 20   용산구                109.426692
# 21   은평구                102.801791
# 22   종로구                114.527438
# 23    중구                117.819264
# 24   중랑구                125.612408

# %%
final_art_achievement_index['Market_Performance_Index'] = cal_df['Market_Performance_Index']
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %%
final_art_achievement_index['art_achievement_index'] = final_art_achievement_index['Enjoyment_Outcome_Index'] + final_art_achievement_index['Market_Performance_Index']
final_art_achievement_index['art_achievement_index'] = final_art_achievement_index['art_achievement_index']/2

# %%
final_art_achievement_index
# Out:
#        구  Arts_and_culture_satisfaction_and_intent_to_attend  \
# 0    강남구                                            55.6881
# 1    강동구                                            55.6881
# 2    강북구                                            55.6881
# 3    강서구                                            55.6881
# 4    관악구                                            55.6881
# 5    광진구                                            55.6881
# 6    구로구                                            55.6881
# 7    금천구                                            55.6881
# 8    노원구                                            55.6881
# 9    도봉구                                            55.6881
# 10  동대문구                                            55.6881
# 11   동작구                                            55.6881
# 12   마포구                                            55.6881
# 13  서대문구                                            55.6881
# 14   서초구                                            55.6881
# ...

# %%
final_art_achievement_index.to_csv('art_achievement_index.csv', encoding='utf-8-sig', index=False)
