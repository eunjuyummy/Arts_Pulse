# %% [markdown]
# # arts_finance_index

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 서울시 구별 데이터
data = {
    '구': ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'],
}
# 데이터 프레임 생성
final_arts_finance_index = pd.DataFrame(data)
final_arts_finance_index
# Out:
#        구
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
art_finance_index = pd.read_csv('/content/arts_finance_index_calculate.csv')
art_finance_index
# Out:
#        구  cul_budget_2021  cul_budget_2022  cul_government_2021  \
# 0    강남구     7.411000e+11     7.798000e+11                  2.1
# 1    강동구     7.411000e+11     7.798000e+11                  2.1
# 2    강북구     7.411000e+11     7.798000e+11                  2.1
# 3    강서구     7.411000e+11     7.798000e+11                  2.1
# 4    관악구     7.411000e+11     7.798000e+11                  2.1
# 5    광진구     7.411000e+11     7.798000e+11                  2.1
# 6    구로구     7.411000e+11     7.798000e+11                  2.1
# 7    금천구     7.411000e+11     7.798000e+11                  2.1
# 8    노원구     7.411000e+11     7.798000e+11                  2.1
# 9    도봉구     7.411000e+11     7.798000e+11                  2.1
# 10  동대문구     7.411000e+11     7.798000e+11                  2.1
# 11   동작구     7.411000e+11     7.798000e+11                  2.1
# 12   마포구     7.411000e+11     7.798000e+11                  2.1
# 13  서대문구     7.411000e+11     7.798000e+11                  2.1
# ...

# %% [markdown]
# ## 문화예술 부서 예산

# %%
final_arts_finance_index['cul_budget'] = art_finance_index['cul_budget_2022'] / art_finance_index['cul_budget_2021']
final_arts_finance_index['cul_budget'] = (final_arts_finance_index['cul_budget']*100).round(2)
final_arts_finance_index
# Out:
#        구  cul_budget
# 0    강남구      105.22
# 1    강동구      105.22
# 2    강북구      105.22
# 3    강서구      105.22
# 4    관악구      105.22
# 5    광진구      105.22
# 6    구로구      105.22
# 7    금천구      105.22
# 8    노원구      105.22
# 9    도봉구      105.22
# 10  동대문구      105.22
# 11   동작구      105.22
# 12   마포구      105.22
# 13  서대문구      105.22
# 14   서초구      105.22
# 15   성동구      105.22
# 16   성북구      105.22
# 17   송파구      105.22
# 18   양천구      105.22
# 19  영등포구      105.22
# 20   용산구      105.22
# 21   은평구      105.22
# 22   종로구      105.22
# 23    중구      105.22
# 24   중랑구      105.22

# %% [markdown]
# ## 전체 예산 대비 문화예술 부서 예산

# %%
final_arts_finance_index['cul_government'] = art_finance_index['cul_government_2022'] / art_finance_index['cul_government_2021']
final_arts_finance_index['cul_government'] = (final_arts_finance_index['cul_government']*100).round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government
# 0    강남구      105.22           95.24
# 1    강동구      105.22           95.24
# 2    강북구      105.22           95.24
# 3    강서구      105.22           95.24
# 4    관악구      105.22           95.24
# 5    광진구      105.22           95.24
# 6    구로구      105.22           95.24
# 7    금천구      105.22           95.24
# 8    노원구      105.22           95.24
# 9    도봉구      105.22           95.24
# 10  동대문구      105.22           95.24
# 11   동작구      105.22           95.24
# 12   마포구      105.22           95.24
# 13  서대문구      105.22           95.24
# 14   서초구      105.22           95.24
# 15   성동구      105.22           95.24
# 16   성북구      105.22           95.24
# 17   송파구      105.22           95.24
# 18   양천구      105.22           95.24
# 19  영등포구      105.22           95.24
# 20   용산구      105.22           95.24
# 21   은평구      105.22           95.24
# 22   종로구      105.22           95.24
# 23    중구      105.22           95.24
# ...

# %% [markdown]
# ## 문화예술 예산

# %%
final_arts_finance_index['cna_budget'] = art_finance_index['cna_budget_2022'] / art_finance_index['cna_budget_2021']
final_arts_finance_index['cna_budget'] = (final_arts_finance_index['cna_budget']*100).round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget
# 0    강남구      105.22           95.24       101.5
# 1    강동구      105.22           95.24       101.5
# 2    강북구      105.22           95.24       101.5
# 3    강서구      105.22           95.24       101.5
# 4    관악구      105.22           95.24       101.5
# 5    광진구      105.22           95.24       101.5
# 6    구로구      105.22           95.24       101.5
# 7    금천구      105.22           95.24       101.5
# 8    노원구      105.22           95.24       101.5
# 9    도봉구      105.22           95.24       101.5
# 10  동대문구      105.22           95.24       101.5
# 11   동작구      105.22           95.24       101.5
# 12   마포구      105.22           95.24       101.5
# 13  서대문구      105.22           95.24       101.5
# 14   서초구      105.22           95.24       101.5
# 15   성동구      105.22           95.24       101.5
# 16   성북구      105.22           95.24       101.5
# 17   송파구      105.22           95.24       101.5
# ...

# %% [markdown]
# ## 문화예술 부서 예산 대비 문화예술 예산

# %%
final_arts_finance_index['cna_budget_2'] = art_finance_index['cna_budget_2_2022'] / art_finance_index['cna_budget_2_2021']
final_arts_finance_index['cna_budget_2'] = (final_arts_finance_index['cna_budget_2']*100).round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget  cna_budget_2
# 0    강남구      105.22           95.24       101.5         96.45
# 1    강동구      105.22           95.24       101.5         96.45
# 2    강북구      105.22           95.24       101.5         96.45
# 3    강서구      105.22           95.24       101.5         96.45
# 4    관악구      105.22           95.24       101.5         96.45
# 5    광진구      105.22           95.24       101.5         96.45
# 6    구로구      105.22           95.24       101.5         96.45
# 7    금천구      105.22           95.24       101.5         96.45
# 8    노원구      105.22           95.24       101.5         96.45
# 9    도봉구      105.22           95.24       101.5         96.45
# 10  동대문구      105.22           95.24       101.5         96.45
# 11   동작구      105.22           95.24       101.5         96.45
# 12   마포구      105.22           95.24       101.5         96.45
# 13  서대문구      105.22           95.24       101.5         96.45
# ...

# %% [markdown]
# ## 기업의 문화예술 기부액

# %%
art_finance_index['donation_2021']
# Out:
# 0     216256860
# 1      25639089
# 2       6000000
# 3     199885463
# 4     300000000
# 5      19122230
# 6      29969760
# 7     826131489
# 8     646908000
# 9             0
# 10     24450000
# 11            0
# 12     26723932
# 13    129901117
# 14    100000000
# 15    112188900
# 16     45168223
# 17     33034000
# 18     25842285
# 19     23584119
# 20     35000000
# 21      3940000
# 22     35881348
# 23    252000000
# 24    129901117
# Name: donation_2021, dtype: int64

# %%
art_finance_index['donation_2022']
# Out:
# 0     531102360
# 1      40680629
# 2             0
# 3     134933650
# 4     318440000
# 5      79485450
# 6       2000000
# 7      27590000
# 8     676577200
# 9             0
# 10     24450000
# 11            0
# 12     26723932
# 13    137689823
# 14    670278550
# 15    200031499
# 16     43191123
# 17     13373350
# 18     25842285
# 19      3433362
# 20            0
# 21     60851200
# 22     35881348
# 23    252000000
# 24    137689823
# Name: donation_2022, dtype: int64

# %%
art_finance_index['donation_2022'] / art_finance_index['donation_2021']
# Out:
# 0      2.455887
# 1      1.586664
# 2      0.000000
# 3      0.675055
# 4      1.061467
# 5      4.156704
# 6      0.066734
# 7      0.033397
# 8      1.045863
# 9           NaN
# 10     1.000000
# 11          NaN
# 12     1.000000
# 13     1.059959
# 14     6.702786
# 15     1.782988
# 16     0.956228
# 17     0.404836
# 18     1.000000
# 19     0.145579
# 20     0.000000
# 21    15.444467
# 22     1.000000
# 23     1.000000
# 24     1.059959
# dtype: float64

# %%
final_arts_finance_index['donation'] = art_finance_index['donation_2022'] / art_finance_index['donation_2021']
final_arts_finance_index['donation'] = (final_arts_finance_index['donation']*100).round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget  cna_budget_2  donation
# 0    강남구      105.22           95.24       101.5         96.45    245.59
# 1    강동구      105.22           95.24       101.5         96.45    158.67
# 2    강북구      105.22           95.24       101.5         96.45      0.00
# 3    강서구      105.22           95.24       101.5         96.45     67.51
# 4    관악구      105.22           95.24       101.5         96.45    106.15
# 5    광진구      105.22           95.24       101.5         96.45    415.67
# 6    구로구      105.22           95.24       101.5         96.45      6.67
# 7    금천구      105.22           95.24       101.5         96.45      3.34
# 8    노원구      105.22           95.24       101.5         96.45    104.59
# 9    도봉구      105.22           95.24       101.5         96.45       NaN
# 10  동대문구      105.22           95.24       101.5         96.45    100.00
# 11   동작구      105.22           95.24       101.5         96.45       NaN
# ...

# %% [markdown]
# ### Nan -> 0으로 변경

# %%
final_arts_finance_index['donation'] = final_arts_finance_index['donation'].fillna(0)

# %%
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget  cna_budget_2  donation
# 0    강남구      105.22           95.24       101.5         96.45    245.59
# 1    강동구      105.22           95.24       101.5         96.45    158.67
# 2    강북구      105.22           95.24       101.5         96.45      0.00
# 3    강서구      105.22           95.24       101.5         96.45     67.51
# 4    관악구      105.22           95.24       101.5         96.45    106.15
# 5    광진구      105.22           95.24       101.5         96.45    415.67
# 6    구로구      105.22           95.24       101.5         96.45      6.67
# 7    금천구      105.22           95.24       101.5         96.45      3.34
# 8    노원구      105.22           95.24       101.5         96.45    104.59
# 9    도봉구      105.22           95.24       101.5         96.45      0.00
# 10  동대문구      105.22           95.24       101.5         96.45    100.00
# 11   동작구      105.22           95.24       101.5         96.45      0.00
# ...

# %% [markdown]
# ## 예산지수

# %%
final_arts_finance_index['budget_index'] = final_arts_finance_index['cul_budget'] + final_arts_finance_index['cul_government'] + final_arts_finance_index['cna_budget'] + final_arts_finance_index['cna_budget_2']
final_arts_finance_index['budget_index'] = final_arts_finance_index['budget_index']/4
final_arts_finance_index['budget_index'] = final_arts_finance_index['budget_index'].round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget  cna_budget_2  donation  \
# 0    강남구      105.22           95.24       101.5         96.45    245.59
# 1    강동구      105.22           95.24       101.5         96.45    158.67
# 2    강북구      105.22           95.24       101.5         96.45      0.00
# 3    강서구      105.22           95.24       101.5         96.45     67.51
# 4    관악구      105.22           95.24       101.5         96.45    106.15
# 5    광진구      105.22           95.24       101.5         96.45    415.67
# 6    구로구      105.22           95.24       101.5         96.45      6.67
# 7    금천구      105.22           95.24       101.5         96.45      3.34
# 8    노원구      105.22           95.24       101.5         96.45    104.59
# 9    도봉구      105.22           95.24       101.5         96.45      0.00
# 10  동대문구      105.22           95.24       101.5         96.45    100.00
# 11   동작구      105.22           95.24       101.5         96.45      0.00
# ...

# %% [markdown]
# ## 기부지수

# %%
final_arts_finance_index['donation_index'] = final_arts_finance_index['donation']
final_arts_finance_index['donation_index'] = final_arts_finance_index['donation_index'].round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget  cna_budget_2  donation  \
# 0    강남구      105.22           95.24       101.5         96.45    245.59
# 1    강동구      105.22           95.24       101.5         96.45    158.67
# 2    강북구      105.22           95.24       101.5         96.45      0.00
# 3    강서구      105.22           95.24       101.5         96.45     67.51
# 4    관악구      105.22           95.24       101.5         96.45    106.15
# 5    광진구      105.22           95.24       101.5         96.45    415.67
# 6    구로구      105.22           95.24       101.5         96.45      6.67
# 7    금천구      105.22           95.24       101.5         96.45      3.34
# 8    노원구      105.22           95.24       101.5         96.45    104.59
# 9    도봉구      105.22           95.24       101.5         96.45      0.00
# 10  동대문구      105.22           95.24       101.5         96.45    100.00
# 11   동작구      105.22           95.24       101.5         96.45      0.00
# ...

# %% [markdown]
# ## 예술재정지수

# %%
final_arts_finance_index['arts_finance_index'] = final_arts_finance_index['budget_index'] + final_arts_finance_index['donation_index']
final_arts_finance_index['arts_finance_index'] = final_arts_finance_index['arts_finance_index']/2
final_arts_finance_index['arts_finance_index'] = final_arts_finance_index['arts_finance_index'].round(2)
final_arts_finance_index
# Out:
#        구  cul_budget  cul_government  cna_budget  cna_budget_2  donation  \
# 0    강남구      105.22           95.24       101.5         96.45    245.59
# 1    강동구      105.22           95.24       101.5         96.45    158.67
# 2    강북구      105.22           95.24       101.5         96.45      0.00
# 3    강서구      105.22           95.24       101.5         96.45     67.51
# 4    관악구      105.22           95.24       101.5         96.45    106.15
# 5    광진구      105.22           95.24       101.5         96.45    415.67
# 6    구로구      105.22           95.24       101.5         96.45      6.67
# 7    금천구      105.22           95.24       101.5         96.45      3.34
# 8    노원구      105.22           95.24       101.5         96.45    104.59
# 9    도봉구      105.22           95.24       101.5         96.45      0.00
# 10  동대문구      105.22           95.24       101.5         96.45    100.00
# 11   동작구      105.22           95.24       101.5         96.45      0.00
# ...

# %%
final_arts_finance_index['cul_budget'].describe()
# Out:
# count    2.500000e+01
# mean     1.052200e+02
# std      1.450389e-14
# min      1.052200e+02
# 25%      1.052200e+02
# 50%      1.052200e+02
# 75%      1.052200e+02
# max      1.052200e+02
# Name: cul_budget, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['cul_budget'].plot(kind='bar')
plt.title('cul_budget')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['cul_government'].describe()
# Out:
# count    2.500000e+01
# mean     9.524000e+01
# std      1.450389e-14
# min      9.524000e+01
# 25%      9.524000e+01
# 50%      9.524000e+01
# 75%      9.524000e+01
# max      9.524000e+01
# Name: cul_government, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['cul_government'].plot(kind='bar')
plt.title('cul_government')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['cna_budget'].describe()
# Out:
# count     25.0
# mean     101.5
# std        0.0
# min      101.5
# 25%      101.5
# 50%      101.5
# 75%      101.5
# max      101.5
# Name: cna_budget, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['cna_budget'].plot(kind='bar')
plt.title('cna_budget')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['cna_budget_2'].describe()
# Out:
# count    25.00
# mean     96.45
# std       0.00
# min      96.45
# 25%      96.45
# 50%      96.45
# 75%      96.45
# max      96.45
# Name: cna_budget_2, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['cna_budget_2'].plot(kind='bar')
plt.title('cna_budget_2')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['donation'].describe()
# Out:
# count      25.000000
# mean      174.555200
# std       321.014806
# min         0.000000
# 25%        14.560000
# 50%       100.000000
# 75%       106.150000
# max      1544.450000
# Name: donation, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['donation'].plot(kind='bar')
plt.title('donation')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['budget_index'].describe()
# Out:
# count    2.500000e+01
# mean     9.960000e+01
# std      1.450389e-14
# min      9.960000e+01
# 25%      9.960000e+01
# 50%      9.960000e+01
# 75%      9.960000e+01
# max      9.960000e+01
# Name: budget_index, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['budget_index'].plot(kind='bar')
plt.title('budget_index')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['donation_index'].describe()
# Out:
# count      25.000000
# mean      174.555200
# std       321.014806
# min         0.000000
# 25%        14.560000
# 50%       100.000000
# 75%       106.150000
# max      1544.450000
# Name: donation_index, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['donation_index'].plot(kind='bar')
plt.title('donation_index')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index['arts_finance_index'].describe()
# Out:
# count     25.000000
# mean     137.078800
# std      160.506438
# min       49.800000
# 25%       57.080000
# 50%       99.800000
# 75%      102.880000
# max      822.020000
# Name: arts_finance_index, dtype: float64

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 새로운 figure 생성 및 크기 설정
plt.figure(figsize=(10, 6))  # 가로크기 10, 세로크기 6

final_arts_finance_index['arts_finance_index'].plot(kind='bar')
plt.title('arts_finance_index')

# x축에 구별 이름 추가
districts = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
plt.xticks(range(len(districts)), districts, rotation=45, ha='right')

plt.show()

# %%
final_arts_finance_index.to_csv('arts_finance_index.csv', encoding='utf-8-sig', index=False)
